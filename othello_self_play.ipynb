# %% [markdown]
# # オセロモデル製作
# # ～セルフプレイ部～
#
# ここではモデルを学習する際に必要な学習データ，対局データを自己対決によって製作する．

# %% [markdown]
# ## 1．プログラムのアップロード
#
# 必要となるプログラムをGoogleColab上にアップロードする．
# プログラムの一覧を以下に記す．
#
# - _train_cycle_to_selfplay.py
# - dual_network.py
# - game.py
# - pv_mcts.py
# - self_play_2.py

# %%
# サンプルのソースコード一式のアップロード
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be39fd58-0ef0-46cb-8cb1-f268618d3ebb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be39fd58-0ef0-46cb-8cb1-f268618d3ebb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 2．学習モデルのアップロード
#
# 既に製作済みの学習モデルがある場合（学習サイクル2週目から），学習モデルをアップロードする．
# アップロードするモデルは以下の通り．
#
# - best.h5

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1161e055-0732-444c-b137-03f32495b7df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1161e055-0732-444c-b137-03f32495b7df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 3．フォルダの作成
#
# 1. Colab の画面左側，ファイルのアイコンをクリックする（※ 画面上の"ファイル"ではない）．
#
# 1. 表示された画面の空白部分で右クリックをし，新しいフォルダの作成を行う．フォルダ名は「model」．
#
# 1. 「model」フォルダに「best.h5」ファイルをドラッグアンドドロップする．
#
# 1. 完成
#   ![スクリーンショット 2022-10-24 100824.jpg](data:image/jpeg;base64,...)

# %%
# フォルダの確認
# !dir
# Out:
# best.h5		 game.py     sample_data     _train_cycle_to_selfplay.py
# dual_network.py  pv_mcts.py  self_play_2.py

# %% [markdown]
# ## 4．セルフプレイの実行

# %%
# セルフプレイの実行
# !python _train_cycle_to_selfplay.py
# Out:
# Train [ 1 ] ====================
# Beginning of self-play.
# 2022-10-24 01:07:29.644472: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...
# 1/1 [==============================] - 0s 18ms/step
#
# End up to  1 . time:  36.577345848083496
# ...
# 1/1 [==============================] - 0s 17ms/step
# ...
# ...
# 1/1 [==============================] - 0s 19ms/step
#
# End up to  4 . time:  64.29124140739441
# ...
# 1/1 [==============================] - 0s 18ms/step
